# %%
import pandas as pd

# %%
GDP = pd.read_csv("D:\\projects\\global-economic-intelligence\\data\\raw\\gdp.csv", header=2)

# %%
print(GDP.head())
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %%
GDP_growth = pd.read_csv("D:\\projects\\global-economic-intelligence\\data\\raw\\gdp_growth.csv", header=2)

# %%
print(GDP_growth.head())
# Out:
#                   Country Name Country Code         Indicator Name  \
# 0                        Aruba          ABW  GDP growth (annual %)
# 1  Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                  Afghanistan          AFG  GDP growth (annual %)
# 3   Africa Western and Central          AFW  GDP growth (annual %)
# 4                       Angola          AGO  GDP growth (annual %)
#
#       Indicator Code  1960      1961      1962      1963      1964      1965  \
# 0  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 1  NY.GDP.MKTP.KD.ZG   NaN  0.418937  7.937038  5.623764  4.649241  5.138168
# 2  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 3  NY.GDP.MKTP.KD.ZG   NaN  1.869593  3.726090  7.038388  5.364089  4.105339
# 4  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
#
#    ...      2017      2018      2019       2020       2021       2022  \
# 0  ...  3.493430  3.212471  1.225112 -23.897990  14.730616  10.636431
# 1  ...  2.677524  2.705194  2.030077  -2.817572   4.578772   3.722717
# 2  ...  2.647003  1.189228  3.911603  -2.351101 -20.738839  -6.240172
# 3  ...  2.296349  2.904664  3.281683  -3.730630   2.549691   4.472795
# 4  ... -0.149396 -0.594411 -0.204680  -4.042447   2.102753   4.216003
#
#        2023      2024  2025  Unnamed: 70
# 0  7.706798  6.810777   NaN          NaN
# 1  1.931160  2.763839   NaN          NaN
# 2  2.266944       NaN   NaN          NaN
# 3  3.662428  4.585674   NaN          NaN
# 4  1.263308  4.423907   NaN          NaN
#
# [5 rows x 71 columns]

# %%
def process_worldbank_data(file_path, value_name):
    df = pd.read_csv(file_path, header=2)
    df = df.drop(columns=["Indicator Name", "Indicator Code"])
    df = df.melt(
        id_vars=["Country Name", "Country Code"],
        var_name="Year",
        value_name=value_name
    )
    df["Year"] = pd.to_numeric(df["Year"], errors='coerce').astype('Int64')
    return df

# %%
gdp = process_worldbank_data("../data/raw/gdp.csv", "GDP")

gdp_growth = process_worldbank_data("../data/raw/gdp_growth.csv", "GDP_Growth")

inflation = process_worldbank_data("../data/raw/inflation.csv", "Inflation")

unemployment = process_worldbank_data("../data/raw/unemployment.csv", "Unemployment")

population = process_worldbank_data("../data/raw/population.csv", "Population")

exports = process_worldbank_data("../data/raw/exports.csv", "Exports")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 gdp = process_worldbank_data("../data/raw/gdp.csv", "GDP")
#       3 gdp_growth = process_worldbank_data("../data/raw/gdp_growth.csv", "GDP_Growth")
#       5 inflation = process_worldbank_data("../data/raw/inflation.csv", "Inflation")
#
# Cell In[16], line 11, in process_worldbank_data(file_path, value_name)
#       3 df = pd.read_csv(file_path, skiprows=4)
#       5 df = df.melt(
#       6     id_vars=["Country Name", "Country Code"],
#       7     var_name="Year",
#       8     value_name=value_name
#       9 )
# ---> 11 df["Year"] = df["Year"].astype(int)
#      13 return df
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\arrays\string_.py:944, in StringArray.astype(self, dtype, copy)
#     941     values[mask] = np.nan
#     942     return values
# --> 944 return super().astype(dtype, copy)
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\arrays\numpy_.py:280, in NumpyExtensionArray.astype(self, dtype, copy)
#     277         return self.copy()
#     278     return self
# --> 280 result = astype_array(self._ndarray, dtype=dtype, copy=copy)
#     281 return result
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\dtypes\astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File d:\projects\global-economic-intelligence\.myenv\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or object in (arr.dtype, dtype):
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Indicator Name'
